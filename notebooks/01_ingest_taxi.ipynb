# %%
display(dbutils.fs.ls("/databricks-datasets/nyctaxi/tripdata/"))
display(dbutils.fs.ls("/databricks-datasets/nyctaxi/tripdata/yellow/"))

# %%
source_path = "/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009*.csv.gz"

raw_df = (
    spark.read
    .option("header","true")
    .option("inferSchema","true")
    .csv(source_path)
)

display(raw_df.limit(1))

print("Rows:", raw_df.count())
print("Columns:", raw_df.columns)

(
    raw_df.write
    .format("delta")
    .mode("overwrite")
    .saveAsTable("nyctaxi_dev.bronze.yellow_taxi_raw")
)

# %%
spark.sql("DESCRIBE TABLE nyctaxi_dev.bronze.yellow_taxi_raw").show()
